# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Data

# %%
df = pd.read_csv("/Users/godfather_101/Downloads/New Folder With Items/Instagram Analysis/Instagram data.csv",encoding="latin-1")
df.head()
# Out:
#    Impressions  From Home  From Hashtags  From Explore  From Other  Saves  \
# 0         3920       2586           1028           619          56     98
# 1         5394       2727           1838          1174          78    194
# 2         4021       2085           1188             0         533     41
# 3         4528       2700            621           932          73    172
# 4         2518       1704            255           279          37     96
#
#    Comments  Shares  Likes  Profile Visits  Follows  \
# 0         9       5    162              35        2
# 1         7      14    224              48       10
# 2        11       1    131              62       12
# 3        10       7    213              23        8
# 4         5       4    123               8        0
#
#                                              Caption  \
# 0  Here are some of the most important data visua...
# 1  Here are some of the best data science project...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119 entries, 0 to 118
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Impressions     119 non-null    int64
#  1   From Home       119 non-null    int64
#  2   From Hashtags   119 non-null    int64
#  3   From Explore    119 non-null    int64
#  4   From Other      119 non-null    int64
#  5   Saves           119 non-null    int64
#  6   Comments        119 non-null    int64
#  7   Shares          119 non-null    int64
#  8   Likes           119 non-null    int64
#  9   Profile Visits  119 non-null    int64
#  10  Follows         119 non-null    int64
#  11  Caption         119 non-null    object
#  12  Hashtags        119 non-null    object
# dtypes: int64(11), object(2)
# memory usage: 12.2+ KB

# %%
from wordcloud import WordCloud
wc = WordCloud()

# %%
plt.figure(figsize=(10, 5))
plt.imshow(wc.generate(str(df["Hashtags"])), interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.imshow(wc.generate(str(df["Caption"])), interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
categorical_data = [col for col in df.columns if df[col].dtypes=="O"]
numerical_data = [col for col in df.columns if df[col].dtypes!="O"]

# %%
import seaborn as sns

# %%
sns.heatmap(df[numerical_data].corr(),annot=True)
plt.show()

# %%
df.describe()
# Out:
#         Impressions     From Home  From Hashtags  From Explore   From Other  \
# count    119.000000    119.000000     119.000000    119.000000   119.000000
# mean    5703.991597   2475.789916    1887.512605   1078.100840   171.092437
# std     4843.780105   1489.386348    1884.361443   2613.026132   289.431031
# min     1941.000000   1133.000000     116.000000      0.000000     9.000000
# 25%     3467.000000   1945.000000     726.000000    157.500000    38.000000
# 50%     4289.000000   2207.000000    1278.000000    326.000000    74.000000
# 75%     6138.000000   2602.500000    2363.500000    689.500000   196.000000
# max    36919.000000  13473.000000   11817.000000  17414.000000  2547.000000
#
#              Saves    Comments      Shares       Likes  Profile Visits  \
# count   119.000000  119.000000  119.000000  119.000000      119.000000
# mean    153.310924    6.663866    9.361345  173.781513       50.621849
# ...

# %%
df.plot(kind="box",figsize=(15,7))
# Out:
# <Axes: >

# %%
df.groupby("Saves")["From Home"].sum().plot()
# Out:
# <Axes: xlabel='Saves'>

# %%
sns.scatterplot(x=df["From Hashtags"],y=df["From Home"],hue=df["Comments"])
plt.show()

# %%
sns.scatterplot(x=df["From Explore"],y=df["From Other"],hue=df["Likes"])
plt.show()

# %% [markdown]
# ### Data Preprocessing

# %%
df.head()
# Out:
#    Impressions  From Home  From Hashtags  From Explore  From Other  Saves  \
# 0         3920       2586           1028           619          56     98
# 1         5394       2727           1838          1174          78    194
# 2         4021       2085           1188             0         533     41
# 3         4528       2700            621           932          73    172
# 4         2518       1704            255           279          37     96
#
#    Comments  Shares  Likes  Profile Visits  Follows  \
# 0         9       5    162              35        2
# 1         7      14    224              48       10
# 2        11       1    131              62       12
# 3        10       7    213              23        8
# 4         5       4    123               8        0
#
#                                              Caption  \
# 0  Here are some of the most important data visua...
# 1  Here are some of the best data science project...
# ...

# %%
X = df[["Saves","Likes","Profile Visits","Follows","Shares"]]
y = df["Impressions"]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=.2,random_state=2,shuffle=True)

# %% [markdown]
# ### Model

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier(random_state=0)
model.fit(X_train,y_train)
# Out:
# RandomForestClassifier(random_state=0)

# %%
model.score(X_train,y_train)
# Out:
# 1.0

# %%
y_pred = model.predict(X_test)
from sklearn.metrics import r2_score,mean_squared_error
print("R2_Score :",r2_score(y_pred,y_test))
print("mean_squared_error :",mean_squared_error(y_pred,y_test))
print("RMSE :",np.sqrt(mean_squared_error(y_pred,y_test)))
# Out:
# R2_Score : 0.7388441551852933
# mean_squared_error : 928920.7083333334
# RMSE : 963.8053269894981

# %%
import joblib
joblib.dump(model,"Model - Insta Analysis")
# Out:
# ['Model - Insta Analysis']
